# %% [markdown]
# # Setup
#
# In this notebook, we'll setup all the resources we need to work on Lab 1, 2 and 3

# %% [markdown]
# ## Step 1
#
# Go to https://www.kaggle.com/competitions/titanic/data and download the dataset and save the CSV files locally.​
#
# ![Titanic Data](./resource/titanic_data.png)

# %% [markdown]
# ## Step 2
#
# Go to Databricks. Create a new catalog called "ml_catalog",
#
# ![Add Catalog](./resource/add_catalog.png)
#
# ![Create catalog](./resource/create_catalog.png)

# %% [markdown]
# ## Step 3
#
# then create a new schema called "titanic_schema"
#
# ![where create_schema](./resource/where_create_schema.png)
#
# ![create_schema](./resource/create_schema.png)

# %% [markdown]
# ## Step 3
#
# inside the schema. Upload the Titanic CSV files and create managed Delta tables inside "titanic_schema“. Unity Catalog uses the catalog.schema.table hierarchy to organize data objects.​
#
# ![create_table](./resource/create_table.png)
